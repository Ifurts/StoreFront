# %%
import pandas as pd

# %%
#Carregue um arquivo CSV contendo dados de uma planilha e crie um DataFrame com o Pandas.

Bankchurn = 'C:\\Users\\ifurtado\\Documents\\Trilha Interna\\BankChurners.csv'
DF = pd.read_csv(Bankchurn)

# %%
#2 Exiba as primeiras linhas do DataFrame para verificar os dados que foram carregados.

DF.head(5)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
#3 Verifique o número de linhas e colunas presentes no DataFrame.

DF.shape
# Out:
# (10127, 23)

# %%
#4 Utilize o método info() para obter informações sobre os tipos de dados e a
# contagem de valores não nulos em cada coluna.

DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
#5 Selecione uma coluna específica do DataFrame e exiba suas estatísticas básicas usando o método describe().
DF['Education_Level'].describe()
# Out:
# count        10127
# unique           7
# top       Graduate
# freq          3128
# Name: Education_Level, dtype: object

# %%
#6 Faça uma filtragem no DataFrame para exibir apenas as linhas que atendam a determinada condição.

#DF['Education_Level'].unique()

Edu_Level_filter = DF['Education_Level'].isin(['College', 'Graduate', 'Post-Graduate', 'Doctorare'])

filtered_DF = DF[Edu_Level_filter]

filtered_DF
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 5      713061558  Existing Customer            44      M                2
# 9      719661558  Existing Customer            48      M                2
# 12     710599683  Existing Customer            56      M                1
# ...          ...                ...           ...    ...              ...
# 10117  712503408  Existing Customer            57      M                2
# 10121  713899383  Existing Customer            56      F                1
# 10122  772366833  Existing Customer            50      M                2
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
# 7 Crie uma nova coluna no DataFrame, calculando-a com base em outras colunas existentes.
filtered_DF.loc [: , 'Total_Cash'] = filtered_DF['Total_Revolving_Bal'] + filtered_DF['Avg_Open_To_Buy']
filtered_DF
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 5      713061558  Existing Customer            44      M                2
# 9      719661558  Existing Customer            48      M                2
# 12     710599683  Existing Customer            56      M                1
# ...          ...                ...           ...    ...              ...
# 10117  712503408  Existing Customer            57      M                2
# 10121  713899383  Existing Customer            56      F                1
# 10122  772366833  Existing Customer            50      M                2
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
#8 Agrupe o DataFrame com base em uma coluna específica
# e realize uma operação de agregação, como soma, média ou contagem.

GroupByEducationLevel = filtered_DF.groupby('Education_Level')

MediaTotalCash = GroupByEducationLevel['Total_Cash'].mean().round().astype(int)

FormatReturnPrint = pd.DataFrame({'Education_Level': MediaTotalCash.index,'Média Total Cash': MediaTotalCash.values})

print ('Media Total Cash per education Level:\n', FormatReturnPrint)
# Out:
# Media Total Cash per education Level:
#    Education_Level  Média Total Cash
# 0         College              8685
# 1        Graduate              8566
# 2   Post-Graduate              8863

# %%
# 9 teste def

def saudacao(nome):
    mensagem = f"Olá, {nome}!"
    return mensagem

nome_pessoa = "Michele"
mensagem_saudacao = saudacao(nome_pessoa)
print(mensagem_saudacao)
# Out:
# Olá, Michele!
